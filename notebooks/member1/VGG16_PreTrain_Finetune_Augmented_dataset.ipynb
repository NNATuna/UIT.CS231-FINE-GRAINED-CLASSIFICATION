# %% [markdown]
# # Huấn luyện VGG16 từ ZIP trên Google Drive rồi copy sang local Colab
#
# Notebook này làm theo đúng flow:
#
# - Mount Google Drive
# - Copy **1 file ZIP** từ Drive sang `/content`
# - Giải nén ZIP vào local của Colab
# - Tự tìm đúng thư mục chứa `train/`, `val/`, `test`
# - Dùng **VGG16**
# - Ảnh resize về **128x128**
# - `BATCH_SIZE = 32`
# - Mỗi epoch có:
#   - `accuracy`
#   - `val_accuracy`
#   - `loss`
#   - `val_loss`
#   - `learning_rate`
# - Mỗi epoch sẽ lưu **model tốt nhất** theo `val_accuracy`
# - Cuối cùng đánh giá trên:
#   - tập **train**
#   - tập **test**

# %% [markdown]
# ## 1. Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. Khai báo đường dẫn và tham số
#
# Bạn chỉ cần sửa:
# - `ZIP_PATH_IN_DRIVE`
# - `OUTPUT_DIR`

# %%
import os

# ====== SỬA 2 DÒNG NÀY ======
ZIP_PATH_IN_DRIVE = "/content/drive/MyDrive/augmented_dataset.zip"
OUTPUT_DIR = "/content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs"
# ============================

LOCAL_ZIP_PATH = "/content/augmented_dataset.zip"
LOCAL_EXTRACT_DIR = "/content/augmented_dataset_local"

IMG_SIZE = (128, 128)
BATCH_SIZE = 32
EPOCHS_HEAD = 15
EPOCHS_FINE_TUNE = 5
SEED = 42

os.makedirs(OUTPUT_DIR, exist_ok=True)

print("ZIP_PATH_IN_DRIVE:", ZIP_PATH_IN_DRIVE)
print("LOCAL_ZIP_PATH   :", LOCAL_ZIP_PATH)
print("LOCAL_EXTRACT_DIR:", LOCAL_EXTRACT_DIR)
print("OUTPUT_DIR       :", OUTPUT_DIR)
# Out:
# ZIP_PATH_IN_DRIVE: /content/drive/MyDrive/augmented_dataset.zip
# LOCAL_ZIP_PATH   : /content/augmented_dataset.zip
# LOCAL_EXTRACT_DIR: /content/augmented_dataset_local
# OUTPUT_DIR       : /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs

# %% [markdown]
# ## 3. Copy ZIP sang local của Colab và giải nén
#
# Đây là flow nhanh hơn nhiều so với đọc trực tiếp từ Google Drive.

# %%
assert os.path.exists(ZIP_PATH_IN_DRIVE), f"Không tìm thấy file ZIP: {ZIP_PATH_IN_DRIVE}"

if not os.path.exists(LOCAL_ZIP_PATH):
    print("Đang copy ZIP sang local của Colab ...")
    # !cp "$ZIP_PATH_IN_DRIVE" "$LOCAL_ZIP_PATH"
    print("Copy ZIP xong.")
else:
    print("ZIP đã có sẵn ở local, bỏ qua bước copy.")

if not os.path.exists(LOCAL_EXTRACT_DIR):
    os.makedirs(LOCAL_EXTRACT_DIR, exist_ok=True)
    print("Đang giải nén ZIP ...")
    # !unzip -q "$LOCAL_ZIP_PATH" -d "$LOCAL_EXTRACT_DIR"
    print("Giải nén xong.")
else:
    print("Đã có thư mục local extract, bỏ qua bước giải nén.")
# Out:
# Đang copy ZIP sang local của Colab ...
# Copy ZIP xong.
# Đang giải nén ZIP ...
# Giải nén xong.

# %% [markdown]
# ## 4. Tự tìm thư mục dataset có `train/`, `val/`, `test`

# %%
import os

def find_dataset_root(base_dir):
    for root, dirs, files in os.walk(base_dir):
        dir_names = set(dirs)
        if {"train", "val", "test"}.issubset(dir_names):
            return root
    return None

DATASET_DIR = find_dataset_root(LOCAL_EXTRACT_DIR)
assert DATASET_DIR is not None, "Không tìm thấy thư mục chứa train/val/test sau khi giải nén."

TRAIN_DIR = os.path.join(DATASET_DIR, "train")
VAL_DIR = os.path.join(DATASET_DIR, "val")
TEST_DIR = os.path.join(DATASET_DIR, "test")

print("DATASET_DIR:", DATASET_DIR)
print("TRAIN_DIR  :", TRAIN_DIR)
print("VAL_DIR    :", VAL_DIR)
print("TEST_DIR   :", TEST_DIR)
# Out:
# DATASET_DIR: /content/augmented_dataset_local
# TRAIN_DIR  : /content/augmented_dataset_local/train
# VAL_DIR    : /content/augmented_dataset_local/val
# TEST_DIR   : /content/augmented_dataset_local/test

# %% [markdown]
# ## 5. Import thư viện

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input

np.random.seed(SEED)
tf.random.set_seed(SEED)

print("TensorFlow version:", tf.__version__)
print("GPU:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.19.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 6. Kiểm tra thư mục dữ liệu

# %%
assert os.path.exists(TRAIN_DIR), f"Không tìm thấy train: {TRAIN_DIR}"
assert os.path.exists(VAL_DIR), f"Không tìm thấy val: {VAL_DIR}"
assert os.path.exists(TEST_DIR), f"Không tìm thấy test: {TEST_DIR}"

print("Đã tìm thấy train / val / test")
print("\n10 class đầu tiên trong train:")
for i, name in enumerate(sorted(os.listdir(TRAIN_DIR))[:10], 1):
    print(f"{i}. {name}")
# Out:
# Đã tìm thấy train / val / test
#
# 10 class đầu tiên trong train:
# 1. ABBOTTS BOOBY
# 2. ABYSSINIAN GROUND HORNBILL
# 3. AFRICAN PIED HORNBILL
# 4. AFRICAN PYGMY GOOSE
# 5. ALPINE CHOUGH
# 6. AMERICAN AVOCET
# 7. AMERICAN BITTERN
# 8. AMERICAN DIPPER
# 9. AMERICAN PIPIT
# 10. AMERICAN WIGEON

# %% [markdown]
# ## 7. Tạo dataset từ thư mục ảnh

# %%
train_ds_raw = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    labels="inferred",
    label_mode="int",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=SEED
)

val_ds_raw = tf.keras.utils.image_dataset_from_directory(
    VAL_DIR,
    labels="inferred",
    label_mode="int",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)

test_ds_raw = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR,
    labels="inferred",
    label_mode="int",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)

class_names = train_ds_raw.class_names
num_classes = len(class_names)

print("Số class:", num_classes)
print("10 class đầu tiên:", class_names[:10])
# Out:
# Found 30000 files belonging to 150 classes.
# Found 4248 files belonging to 150 classes.
# Found 4468 files belonging to 150 classes.
# Số class: 150
# 10 class đầu tiên: ['ABBOTTS BOOBY', 'ABYSSINIAN GROUND HORNBILL', 'AFRICAN PIED HORNBILL', 'AFRICAN PYGMY GOOSE', 'ALPINE CHOUGH', 'AMERICAN AVOCET', 'AMERICAN BITTERN', 'AMERICAN DIPPER', 'AMERICAN PIPIT', 'AMERICAN WIGEON']

# %% [markdown]
# ## 8. Tiền xử lý cho VGG16

# %%
def preprocess_batch(x, y):
    x = tf.cast(x, tf.float32)
    x = preprocess_input(x)
    return x, y

train_ds = train_ds_raw.map(preprocess_batch, num_parallel_calls=2).prefetch(1)
val_ds = val_ds_raw.map(preprocess_batch, num_parallel_calls=2).prefetch(1)
test_ds = test_ds_raw.map(preprocess_batch, num_parallel_calls=2).prefetch(1)

print("Số batch train:", tf.data.experimental.cardinality(train_ds).numpy())
print("Số batch val  :", tf.data.experimental.cardinality(val_ds).numpy())
print("Số batch test :", tf.data.experimental.cardinality(test_ds).numpy())
# Out:
# Số batch train: 938
# Số batch val  : 133
# Số batch test : 140

# %% [markdown]
# ## 9. Xem thử một vài ảnh mẫu

# %%
plt.figure(figsize=(12, 8))
for images, labels in train_ds_raw.take(1):
    for i in range(min(9, len(images))):
        plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[int(labels[i])])
        plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10. Xây dựng model VGG16

# %%
base_model = VGG16(
    include_top=False,
    weights="imagenet",
    input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3)
)
base_model.trainable = False

inputs = layers.Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
x = base_model(inputs, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(num_classes, activation="softmax")(x)

model = models.Model(inputs, outputs)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ vgg16 (Functional)              │ (None, 4, 4, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 150)            │        76,950 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,791,638 (56.43 MB)
#  Trainable params: 76,950 (300.59 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %% [markdown]
# ## 11. Callback lưu best model mỗi epoch và ghi learning rate

# %%
best_model_path = os.path.join(OUTPUT_DIR, "best_vgg16.keras")
final_model_path = os.path.join(OUTPUT_DIR, "final_vgg16.keras")
csv_log_path = os.path.join(OUTPUT_DIR, "training_log.csv")

class LrLogger(callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        lr = self.model.optimizer.learning_rate
        if isinstance(lr, tf.keras.optimizers.schedules.LearningRateSchedule):
            current_lr = float(tf.keras.backend.get_value(lr(self.model.optimizer.iterations)))
        else:
            current_lr = float(tf.keras.backend.get_value(lr))
        logs["learning_rate"] = current_lr
        print(f" - learning_rate: {current_lr:.8f}")

callback_list = [
    callbacks.ModelCheckpoint(
        filepath=best_model_path,
        monitor="val_accuracy",
        mode="max",
        save_best_only=True,
        verbose=1
    ),
    callbacks.CSVLogger(csv_log_path),
    callbacks.EarlyStopping(
        monitor="val_accuracy",
        mode="max",
        patience=4,
        restore_best_weights=True,
        verbose=1
    ),
    callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=2,
        verbose=1
    ),
    LrLogger()
]

print("Best model:", best_model_path)
print("Final model:", final_model_path)
print("CSV log:", csv_log_path)
# Out:
# Best model: /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
# Final model: /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/final_vgg16.keras
# CSV log: /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/training_log.csv

# %% [markdown]
# ## 12. Train phase 1
#
# Khi chạy cell này, mỗi epoch sẽ hiện:
# - accuracy
# - loss
# - val_accuracy
# - val_loss
# - learning_rate

# %%
history_phase1 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_HEAD,
    callbacks=callback_list,
    verbose=1
)
# Out:
# Epoch 1/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.2056 - loss: 16.9846
# Epoch 1: val_accuracy improved from None to 0.75353, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00100000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 87s 83ms/step - accuracy: 0.3852 - loss: 9.3832 - val_accuracy: 0.7535 - val_loss: 1.7932 - learning_rate: 0.0010
# Epoch 2/15
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6830 - loss: 2.7314
# Epoch 2: val_accuracy improved from 0.75353 to 0.79779, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00100000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 73s 77ms/step - accuracy: 0.7043 - loss: 2.4613 - val_accuracy: 0.7978 - val_loss: 1.5918 - learning_rate: 0.0010
# Epoch 3/15
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7624 - loss: 1.8037
# Epoch 3: val_accuracy improved from 0.79779 to 0.80344, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00100000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 77ms/step - accuracy: 0.7701 - loss: 1.7235 - val_accuracy: 0.8034 - val_loss: 1.6036 - learning_rate: 0.0010
# Epoch 4/15
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7916 - loss: 1.5160
# Epoch 4: val_accuracy improved from 0.80344 to 0.81121, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#  - learning_rate: 0.00050000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 82s 77ms/step - accuracy: 0.7975 - loss: 1.4655 - val_accuracy: 0.8112 - val_loss: 1.6620 - learning_rate: 5.0000e-04
# Epoch 5/15
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8363 - loss: 1.0984
# Epoch 5: val_accuracy improved from 0.81121 to 0.84958, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00050000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 72s 77ms/step - accuracy: 0.8474 - loss: 0.9889 - val_accuracy: 0.8496 - val_loss: 1.1856 - learning_rate: 5.0000e-04
# Epoch 6/15
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8541 - loss: 0.9201
# Epoch 6: val_accuracy did not improve from 0.84958
#  - learning_rate: 0.00050000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 72s 77ms/step - accuracy: 0.8580 - loss: 0.8726 - val_accuracy: 0.8491 - val_loss: 1.1767 - learning_rate: 5.0000e-04
# Epoch 7/15
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8639 - loss: 0.8356
# Epoch 7: val_accuracy improved from 0.84958 to 0.85452, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 7: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00050000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 72s 77ms/step - accuracy: 0.8663 - loss: 0.8092 - val_accuracy: 0.8545 - val_loss: 1.2130 - learning_rate: 5.0000e-04
# Epoch 8/15
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8699 - loss: 0.7700
# Epoch 8: val_accuracy did not improve from 0.85452
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#  - learning_rate: 0.00025000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 73s 78ms/step - accuracy: 0.8715 - loss: 0.7567 - val_accuracy: 0.8489 - val_loss: 1.1896 - learning_rate: 2.5000e-04
# Epoch 9/15
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8861 - loss: 0.6250
# Epoch 9: val_accuracy improved from 0.85452 to 0.85664, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 9: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00025000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 72s 77ms/step - accuracy: 0.8926 - loss: 0.5813 - val_accuracy: 0.8566 - val_loss: 1.1092 - learning_rate: 2.5000e-04
# Epoch 10/15
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8960 - loss: 0.5501
# Epoch 10: val_accuracy improved from 0.85664 to 0.85758, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 10: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00025000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 72s 77ms/step - accuracy: 0.8980 - loss: 0.5416 - val_accuracy: 0.8576 - val_loss: 1.0984 - learning_rate: 2.5000e-04
# Epoch 11/15
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8940 - loss: 0.5554
# Epoch 11: val_accuracy improved from 0.85758 to 0.85946, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 11: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00025000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 73s 77ms/step - accuracy: 0.8954 - loss: 0.5445 - val_accuracy: 0.8595 - val_loss: 1.0742 - learning_rate: 2.5000e-04
# Epoch 12/15
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8994 - loss: 0.5122
# Epoch 12: val_accuracy improved from 0.85946 to 0.86064, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 12: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00025000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 72s 77ms/step - accuracy: 0.9001 - loss: 0.5113 - val_accuracy: 0.8606 - val_loss: 1.0894 - learning_rate: 2.5000e-04
# Epoch 13/15
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9054 - loss: 0.4703
# Epoch 13: val_accuracy improved from 0.86064 to 0.86276, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 13: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#  - learning_rate: 0.00012500
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 73s 77ms/step - accuracy: 0.9044 - loss: 0.4801 - val_accuracy: 0.8628 - val_loss: 1.1124 - learning_rate: 1.2500e-04
# Epoch 14/15
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9068 - loss: 0.4521
# Epoch 14: val_accuracy improved from 0.86276 to 0.86511, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 14: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00012500
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 73s 77ms/step - accuracy: 0.9115 - loss: 0.4202 - val_accuracy: 0.8651 - val_loss: 1.0511 - learning_rate: 1.2500e-04
# Epoch 15/15
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9134 - loss: 0.3980
# Epoch 15: val_accuracy improved from 0.86511 to 0.86558, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 15: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00012500
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 73s 78ms/step - accuracy: 0.9153 - loss: 0.3856 - val_accuracy: 0.8656 - val_loss: 1.0396 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 15.

# %% [markdown]
# ## 13. Fine-tune phase 2
#
# Phase này mở một phần base model để tăng accuracy.

# %%
if EPOCHS_FINE_TUNE > 0:
    base_model.trainable = True

    fine_tune_at = int(len(base_model.layers) * 0.8)
    for layer in base_model.layers[:fine_tune_at]:
        layer.trainable = False

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )

    initial_epoch = len(history_phase1.history["loss"])
    total_epochs = initial_epoch + EPOCHS_FINE_TUNE

    history_phase2 = model.fit(
        train_ds,
        validation_data=val_ds,
        initial_epoch=initial_epoch,
        epochs=total_epochs,
        callbacks=callback_list,
        verbose=1
    )
else:
    history_phase2 = None
    print("Đã bỏ qua fine-tune phase 2.")
# Out:
# Epoch 16/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9101 - loss: 0.3553
# Epoch 16: val_accuracy improved from 0.86558 to 0.87029, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 16: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00001000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 100s 101ms/step - accuracy: 0.9146 - loss: 0.3159 - val_accuracy: 0.8703 - val_loss: 0.7131 - learning_rate: 1.0000e-05
# Epoch 17/20
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9379 - loss: 0.2112
# Epoch 17: val_accuracy improved from 0.87029 to 0.88065, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 17: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00001000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 90s 95ms/step - accuracy: 0.9422 - loss: 0.2013 - val_accuracy: 0.8806 - val_loss: 0.6675 - learning_rate: 1.0000e-05
# Epoch 18/20
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9486 - loss: 0.1669
# Epoch 18: val_accuracy did not improve from 0.88065
#  - learning_rate: 0.00001000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 89s 95ms/step - accuracy: 0.9525 - loss: 0.1535 - val_accuracy: 0.8806 - val_loss: 0.6419 - learning_rate: 1.0000e-05
# Epoch 19/20
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9633 - loss: 0.1138
# Epoch 19: val_accuracy improved from 0.88065 to 0.88960, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 19: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00001000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 89s 95ms/step - accuracy: 0.9629 - loss: 0.1177 - val_accuracy: 0.8896 - val_loss: 0.6443 - learning_rate: 1.0000e-05
# Epoch 20/20
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9697 - loss: 0.0968
# Epoch 20: val_accuracy did not improve from 0.88960
#  - learning_rate: 0.00001000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 142s 95ms/step - accuracy: 0.9699 - loss: 0.0947 - val_accuracy: 0.8891 - val_loss: 0.6248 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 19.

# %% [markdown]
# ## 14. Lưu model cuối cùng

# %%
model.save(final_model_path)
print("Đã lưu final model tại:", final_model_path)
# Out:
# Đã lưu final model tại: /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/final_vgg16.keras

# %% [markdown]
# ## 15. Gộp lịch sử train và vẽ biểu đồ

# %%
def combine_history(h1, h2=None):
    if h2 is None:
        return h1.history

    hist = {}
    keys = set(h1.history.keys()).union(set(h2.history.keys()))
    for k in keys:
        hist[k] = h1.history.get(k, []) + h2.history.get(k, [])
    return hist

full_history = combine_history(history_phase1, history_phase2)
history_df = pd.DataFrame(full_history)
display(history_df.head())
# Out:
#    val_accuracy      loss  learning_rate  accuracy  val_loss
# 0      0.753531  9.383181         0.0010  0.385233  1.793187
# 1      0.797787  2.461308         0.0010  0.704267  1.591821
# 2      0.803437  1.723456         0.0010  0.770067  1.603589
# 3      0.811205  1.465502         0.0005  0.797467  1.662036
# 4      0.849576  0.988930         0.0005  0.847433  1.185585

# %%
plt.figure(figsize=(10, 5))
plt.plot(full_history["accuracy"], label="Train Accuracy")
plt.plot(full_history["val_accuracy"], label="Val Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Train vs Validation Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(full_history["loss"], label="Train Loss")
plt.plot(full_history["val_loss"], label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Train vs Validation Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
if "learning_rate" in full_history:
    plt.figure(figsize=(10, 5))
    plt.plot(full_history["learning_rate"], label="Learning Rate")
    plt.xlabel("Epoch")
    plt.ylabel("Learning Rate")
    plt.title("Learning Rate theo Epoch")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
plot_path = os.path.join(OUTPUT_DIR, "accuracy_loss_plot.png")

plt.figure(figsize=(10, 5))
plt.plot(full_history["accuracy"], label="Train Accuracy")
plt.plot(full_history["val_accuracy"], label="Val Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Train vs Validation Accuracy")
plt.legend()
plt.grid(True)
plt.savefig(plot_path, bbox_inches="tight")
plt.close()

print("Đã lưu biểu đồ tại:", plot_path)
# Out:
# Đã lưu biểu đồ tại: /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/accuracy_loss_plot.png

# %% [markdown]
# ## 16. Hàm đánh giá train và test

# %%
def collect_labels_and_predictions(model, dataset):
    y_true = []
    y_pred = []

    for batch_x, batch_y in dataset:
        preds = model.predict(batch_x, verbose=0)
        preds = np.argmax(preds, axis=1)

        y_true.extend(batch_y.numpy().tolist())
        y_pred.extend(preds.tolist())

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    return y_true, y_pred

def evaluate_dataset(model, dataset, split_name):
    y_true, y_pred = collect_labels_and_predictions(model, dataset)

    acc = accuracy_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred, average="macro", zero_division=0)
    rec = recall_score(y_true, y_pred, average="macro", zero_division=0)
    f1 = f1_score(y_true, y_pred, average="macro", zero_division=0)

    print(f"\n===== {split_name.upper()} =====")
    print(f"Accuracy        : {acc:.4f}")
    print(f"Precision macro : {prec:.4f}")
    print(f"Recall macro    : {rec:.4f}")
    print(f"F1 macro        : {f1:.4f}")

    return {
        "split": split_name,
        "accuracy": acc,
        "precision_macro": prec,
        "recall_macro": rec,
        "f1_macro": f1
    }, y_true, y_pred

# %% [markdown]
# ## 17. Đánh giá trên train và test

# %%
train_metrics, y_train_true, y_train_pred = evaluate_dataset(model, train_ds, "train")
test_metrics, y_test_true, y_test_pred = evaluate_dataset(model, test_ds, "test")

metrics_df = pd.DataFrame([train_metrics, test_metrics])
display(metrics_df)
# Out:
# ===== TRAIN =====
# Accuracy        : 0.9990
# Precision macro : 0.9990
# Recall macro    : 0.9990
# F1 macro        : 0.9990
#
# ===== TEST =====
# Accuracy        : 0.8856
# Precision macro : 0.8905
# Recall macro    : 0.8864
# F1 macro        : 0.8864
#    split  accuracy  precision_macro  recall_macro  f1_macro
# 0  train  0.998967         0.998973      0.998967  0.998967
# 1   test  0.885631         0.890537      0.886422  0.886351

# %%
metrics_csv_path = os.path.join(OUTPUT_DIR, "metrics_summary.csv")
metrics_txt_path = os.path.join(OUTPUT_DIR, "metrics_summary.txt")

metrics_df.to_csv(metrics_csv_path, index=False)

with open(metrics_txt_path, "w", encoding="utf-8") as f:
    f.write("KET QUA DANH GIA MO HINH\n")
    f.write("=" * 50 + "\n")
    for row in [train_metrics, test_metrics]:
        f.write(f"Split: {row['split']}\n")
        f.write(f"Accuracy        : {row['accuracy']:.6f}\n")
        f.write(f"Precision macro : {row['precision_macro']:.6f}\n")
        f.write(f"Recall macro    : {row['recall_macro']:.6f}\n")
        f.write(f"F1 macro        : {row['f1_macro']:.6f}\n")
        f.write("-" * 50 + "\n")

print("Đã lưu metrics CSV:", metrics_csv_path)
print("Đã lưu metrics TXT:", metrics_txt_path)
# Out:
# Đã lưu metrics CSV: /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/metrics_summary.csv
# Đã lưu metrics TXT: /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/metrics_summary.txt

# %% [markdown]
# ## 18. Classification report trên tập test

# %%
report = classification_report(
    y_test_true,
    y_test_pred,
    target_names=class_names,
    zero_division=0
)

print(report)

report_path = os.path.join(OUTPUT_DIR, "classification_report_test.txt")
with open(report_path, "w", encoding="utf-8") as f:
    f.write(report)

print("Đã lưu classification report tại:", report_path)
# Out:
#                                precision    recall  f1-score   support
#
#                 ABBOTTS BOOBY       0.71      0.69      0.70        29
#    ABYSSINIAN GROUND HORNBILL       0.96      0.90      0.93        29
#         AFRICAN PIED HORNBILL       0.85      0.97      0.91        30
#           AFRICAN PYGMY GOOSE       0.90      0.93      0.92        29
#                 ALPINE CHOUGH       0.89      0.93      0.91        27
#               AMERICAN AVOCET       0.87      0.93      0.90        29
#              AMERICAN BITTERN       0.84      0.96      0.90        27
#               AMERICAN DIPPER       0.93      0.90      0.92        30
#                AMERICAN PIPIT       0.85      0.97      0.90        29
#               AMERICAN WIGEON       0.76      0.97      0.85        30
#             ASHY STORM PETREL       0.75      0.70      0.72        30
#         ASIAN GREEN BEE EATER       0.94      0.94      0.94        33
#          ASIAN OPENBILL STORK       0.78      0.93      0.85        30
#                 AUCKLAND SHAQ       0.71      0.73      0.72        30
#          AUSTRALASIAN FIGBIRD       0.80      0.80      0.80        30
#              AZARAS SPINETAIL       0.77      0.85      0.81        27
#              BANDED BROADBILL       0.91      0.94      0.92        31
#             BAR-TAILED GODWIT       0.87      1.00      0.93        27
#       BLACK BREASTED PUFFBIRD       1.00      1.00      1.00        27
#           BLACK HEADED CAIQUE       1.00      0.93      0.96        29
#            BLACK NECKED STILT       0.93      0.93      0.93        28
#       BLACK VENTED SHEARWATER       0.83      0.83      0.83        30
#        BLACK-THROATED SPARROW       0.83      0.93      0.88        27
#                   BLUE DACNIS       0.84      0.93      0.88        28
#         BLUE GRAY GNATCATCHER       0.92      0.77      0.84        30
#                 BLUE GROSBEAK       0.96      0.93      0.94        27
#                   BLUE GROUSE       0.73      0.83      0.77        29
#                    BLUE HERON       0.76      0.81      0.79        27
#                  BLUE MALKOHA       0.88      0.93      0.90        30
#     BLUE THROATED PIPING GUAN       0.85      0.71      0.77        31
#             BREWERS BLACKBIRD       0.68      0.66      0.67        29
#                 BROWN CREPPER       0.85      0.79      0.81        28
#          BROWN HEADED COWBIRD       0.70      0.74      0.72        31
#                    BUFFLEHEAD       0.88      0.76      0.81        29
#               CABOTS TRAGOPAN       0.83      0.86      0.84        28
#                 CAMPO FLICKER       1.00      1.00      1.00        31
#                    CANVASBACK       0.90      0.93      0.92        29
#                  CASPIAN TERN       1.00      0.91      0.95        34
#                 CEDAR WAXWING       1.00      0.90      0.95        29
#        CHESTNUT WINGED CUCKOO       0.89      0.89      0.89        27
#              CHUKAR PARTRIDGE       1.00      0.96      0.98        27
#                  CLARKS GREBE       0.93      0.90      0.91        29
#              COLLARED ARACARI       0.96      0.89      0.93        28
#        COLLARED CRESCENTCHEST       0.84      0.93      0.88        28
#                COMMON GRACKLE       1.00      0.75      0.86        28
#            COPPERSMITH BARBET       0.93      0.90      0.92        30
#         CRESTED SERPENT EAGLE       0.71      0.69      0.70        29
#        CRESTED WOOD PARTRIDGE       0.97      0.94      0.95        31
#               CRIMSON SUNBIRD       0.96      0.87      0.92        31
#              D-ARNAUDS BARBET       0.94      0.86      0.90        37
#               DARK EYED JUNCO       0.97      0.91      0.94        32
#      DOUBLE BRESTED CORMARANT       0.83      0.69      0.75        29
#        DOUBLE EYED FIG PARROT       0.81      0.96      0.88        27
#                        DUNLIN       0.93      0.97      0.95        29
#            EASTERN MEADOWLARK       0.91      1.00      0.95        30
#          EASTERN YELLOW ROBIN       1.00      0.97      0.98        32
#            EURASIAN BULLFINCH       0.96      0.89      0.92        27
#                 FLAME TANAGER       0.90      0.96      0.93        28
#                FOREST WAGTAIL       0.83      0.74      0.78        27
#             FRILL BACK PIGEON       0.89      0.94      0.91        33
#                   GLOSSY IBIS       0.93      0.93      0.93        28
#        GOLDEN CHEEKED WARBLER       1.00      0.89      0.94        28
#                   GREAT ARGUS       0.92      0.77      0.84        30
#                GREAT KISKADEE       0.90      0.96      0.93        27
#       GREATER PRAIRIE CHICKEN       1.00      0.97      0.98        32
#           GREATOR SAGE GROUSE       0.96      0.86      0.91        29
#                  GREEN MAGPIE       1.00      0.96      0.98        28
#        GREY HEADED CHACHALACA       0.88      0.94      0.91        31
#                   HARPY EAGLE       0.89      0.86      0.87        28
#                      HAWFINCH       0.92      0.89      0.91        27
#                   HORNED LARK       0.87      0.96      0.92        28
#                   HOUSE FINCH       0.97      0.85      0.90        39
#                  INDIAN PITTA       1.00      0.87      0.93        30
#                 INDIAN ROLLER       0.96      0.93      0.95        29
#                JACOBIN PIGEON       0.94      0.91      0.92        32
#                      KILLDEAR       0.92      0.86      0.89        28
#                    KING EIDER       0.96      0.96      0.96        27
#              KNOB BILLED DUCK       0.82      0.90      0.86        31
#                 LAUGHING GULL       0.85      0.70      0.77        33
#                       LIMPKIN       0.91      0.91      0.91        32
#                    LITTLE AUK       0.85      1.00      0.92        28
#             LOGGERHEAD SHRIKE       0.96      0.87      0.91        30
#           LUCIFER HUMMINGBIRD       0.92      0.85      0.88        27
#                 MARABOU STORK       0.91      0.94      0.92        31
#               MASKED BOBWHITE       0.93      0.93      0.93        29
#                MCKAYS BUNTING       0.93      0.93      0.93        30
#                        MERLIN       0.63      0.79      0.70        33
#                MILITARY MACAW       0.97      0.91      0.94        33
# NORTHERN BEARDLESS TYRANNULET       0.69      0.86      0.77        29
#               NORTHERN PARULA       0.96      0.77      0.86        31
#                       OILBIRD       0.90      1.00      0.95        28
#        ORANGE BREASTED TROGON       0.97      0.90      0.93        31
#             ORNATE HAWK EAGLE       0.73      0.73      0.73        33
#                      OVENBIRD       0.92      0.89      0.90        37
#                OYSTER CATCHER       0.97      1.00      0.99        33
#              PALM NUT VULTURE       0.83      0.94      0.88        31
#              PARADISE TANAGER       0.93      0.93      0.93        28
#                   PHAINOPEPLA       0.96      0.77      0.85        30
#             PLUSH CRESTED JAY       1.00      0.94      0.97        32
#                        PUFFIN       1.00      0.96      0.98        27
#                     PUNA TEAL       0.85      0.97      0.90        29
#              PYGMY KINGFISHER       0.84      0.96      0.90        28
#                   PYRRHULOXIA       0.92      1.00      0.96        33
#                     RAZORBILL       0.94      0.94      0.94        31
#         RED BEARDED BEE EATER       0.94      0.97      0.95        31
#         RED BILLED TROPICBIRD       0.87      0.79      0.83        34
#                 RED CROSSBILL       0.88      0.70      0.78        30
#             RED FACED WARBLER       0.96      0.96      0.96        27
#                      RED FODY       0.93      1.00      0.96        27
#                      RED KNOT       0.90      0.81      0.85        32
#       RED LEGGED HONEYCREEPER       0.96      0.93      0.94        27
#           RED SHOULDERED HAWK       0.71      0.79      0.75        28
#               RED TAILED HAWK       0.57      0.75      0.65        32
#        ROSE BREASTED COCKATOO       0.91      1.00      0.95        31
#        ROSE BREASTED GROSBEAK       1.00      0.96      0.98        28
#             ROSEATE SPOONBILL       1.00      1.00      1.00        31
#          RUBY CROWNED KINGLET       0.87      0.90      0.89        30
#                  RUFOUS TREPE       0.72      0.88      0.79        41
#                 RUFUOS MOTMOT       0.91      0.97      0.94        30
#                SATYR TRAGOPAN       0.92      0.81      0.86        27
#                   SAYS PHOEBE       0.77      0.87      0.82        31
#                      SHOEBILL       0.92      0.86      0.89        28
#                    SNOW GOOSE       0.87      0.90      0.89        30
#                SNOW PARTRIDGE       0.88      0.82      0.85        28
#              SNOWY SHEATHBILL       0.94      1.00      0.97        29
#                          SORA       0.86      0.75      0.80        32
#        SPOTTED WHISTLING DUCK       0.78      0.72      0.75        29
#             STRIATED CARACARA       0.82      0.90      0.86        31
#                    SUNBITTERN       0.85      0.81      0.83        27
#                   SURF SCOTER       0.97      0.97      0.97        29
#             SWINHOES PHEASANT       0.97      0.88      0.92        34
#               TAWNY FROGMOUTH       0.96      0.80      0.87        30
#                  TREE SWALLOW       0.80      0.83      0.81        29
#                 VARIED THRUSH       0.97      0.97      0.97        31
#                         VEERY       0.93      0.83      0.88        30
#                        VERDIN       0.86      0.83      0.84        29
#        VIOLET BACKED STARLING       0.85      0.88      0.86        32
#                 VIOLET CUCKOO       0.85      0.82      0.84        28
#          VIOLET GREEN SWALLOW       0.85      0.72      0.78        32
#          VULTURINE GUINEAFOWL       1.00      1.00      1.00        27
#                  WALL CREAPER       1.00      0.93      0.96        28
#       WHITE EARED HUMMINGBIRD       0.90      0.93      0.91        28
#           WHITE TAILED TROPIC       0.81      0.93      0.87        28
#              WILLOW PTARMIGAN       0.91      1.00      0.95        30
#                     WOOD DUCK       0.97      0.97      0.97        34
#                   WOOD THRUSH       0.90      0.85      0.88        33
#           WOODLAND KINGFISHER       0.97      1.00      0.98        30
#                       WRENTIT       0.77      0.77      0.77        31
#          YELLOW BREASTED CHAT       1.00      0.94      0.97        31
#                    ZEBRA DOVE       0.89      0.93      0.91        27
#
#                      accuracy                           0.89      4468
#                     macro avg       0.89      0.89      0.89      4468
#                  weighted avg       0.89      0.89      0.89      4468
#
# Đã lưu classification report tại: /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/classification_report_test.txt

# %% [markdown]
# ## 19. Hiển thị một vài ảnh dự đoán đúng và sai

# %%
def show_predictions_from_raw_dataset(raw_dataset, y_pred, class_names, correct=True, max_images=9):
    images_all = []
    labels_all = []

    for images, labels in raw_dataset:
        images_all.append(images.numpy().astype("uint8"))
        labels_all.append(labels.numpy())

    X = np.concatenate(images_all, axis=0)
    y_true = np.concatenate(labels_all, axis=0)

    indices = np.where(y_true == y_pred)[0] if correct else np.where(y_true != y_pred)[0]
    if len(indices) == 0:
        print("Không có ảnh phù hợp để hiển thị.")
        return

    chosen = indices[:max_images]

    plt.figure(figsize=(12, 8))
    for i, idx in enumerate(chosen):
        plt.subplot(3, 3, i + 1)
        plt.imshow(X[idx])
        plt.title(f"T:{class_names[y_true[idx]]}\nP:{class_names[y_pred[idx]]}", fontsize=9)
        plt.axis("off")
    plt.tight_layout()
    plt.show()

print("Một vài ảnh dự đoán đúng:")
show_predictions_from_raw_dataset(test_ds_raw, y_test_pred, class_names, correct=True, max_images=9)

print("Một vài ảnh dự đoán sai:")
show_predictions_from_raw_dataset(test_ds_raw, y_test_pred, class_names, correct=False, max_images=9)
# Out:
# Một vài ảnh dự đoán đúng:
# Một vài ảnh dự đoán sai:

# %% [markdown]
# ## 20. Load lại model tốt nhất nếu cần

# %%
best_loaded_model = tf.keras.models.load_model(best_model_path)
print("Đã load best model từ:", best_model_path)

# %% [markdown]
# ## 21. Tóm tắt đầu ra đã lưu
#
# Sau khi chạy xong notebook, trong `OUTPUT_DIR` sẽ có:
# - `best_vgg16.keras`
# - `final_vgg16.keras`
# - `training_log.csv`
# - `accuracy_loss_plot.png`
# - `metrics_summary.csv`
# - `metrics_summary.txt`
# - `classification_report_test.txt`
