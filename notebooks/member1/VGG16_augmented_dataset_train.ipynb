# %% [markdown]
# # Huấn luyện VGG16 từ ZIP trên Google Drive rồi copy sang local Colab
#
# Notebook này làm theo đúng flow:
#
# - Mount Google Drive
# - Copy **1 file ZIP** từ Drive sang `/content`
# - Giải nén ZIP vào local của Colab
# - Tự tìm đúng thư mục chứa `train/`, `val/`, `test`
# - Dùng **VGG16**
# - Ảnh resize về **224x224**
# - `BATCH_SIZE = 32`
# - Mỗi epoch có:
#   - `accuracy`
#   - `val_accuracy`
#   - `loss`
#   - `val_loss`
#   - `learning_rate`
# - Mỗi epoch sẽ lưu **model tốt nhất** theo `val_accuracy`
# - Cuối cùng đánh giá trên:
#   - tập **train**
#   - tập **test**

# %% [markdown]
# ## 1. Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. Khai báo đường dẫn và tham số
#
# Bạn chỉ cần sửa:
# - `ZIP_PATH_IN_DRIVE`
# - `OUTPUT_DIR`

# %%
import os

# ====== SỬA 2 DÒNG NÀY ======
ZIP_PATH_IN_DRIVE = "/content/drive/MyDrive/augmented_dataset.zip"
OUTPUT_DIR = "/content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs"
# ============================

LOCAL_ZIP_PATH = "/content/augmented_dataset.zip"
LOCAL_EXTRACT_DIR = "/content/augmented_dataset_local"

IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS_HEAD = 15
EPOCHS_FINE_TUNE = 5
SEED = 42

os.makedirs(OUTPUT_DIR, exist_ok=True)

print("ZIP_PATH_IN_DRIVE:", ZIP_PATH_IN_DRIVE)
print("LOCAL_ZIP_PATH   :", LOCAL_ZIP_PATH)
print("LOCAL_EXTRACT_DIR:", LOCAL_EXTRACT_DIR)
print("OUTPUT_DIR       :", OUTPUT_DIR)
# Out:
# ZIP_PATH_IN_DRIVE: /content/drive/MyDrive/augmented_dataset.zip
# LOCAL_ZIP_PATH   : /content/augmented_dataset.zip
# LOCAL_EXTRACT_DIR: /content/augmented_dataset_local
# OUTPUT_DIR       : /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs

# %% [markdown]
# ## 3. Copy ZIP sang local của Colab và giải nén
#
# Đây là flow nhanh hơn nhiều so với đọc trực tiếp từ Google Drive.

# %%
assert os.path.exists(ZIP_PATH_IN_DRIVE), f"Không tìm thấy file ZIP: {ZIP_PATH_IN_DRIVE}"

if not os.path.exists(LOCAL_ZIP_PATH):
    print("Đang copy ZIP sang local của Colab ...")
    # !cp "$ZIP_PATH_IN_DRIVE" "$LOCAL_ZIP_PATH"
    print("Copy ZIP xong.")
else:
    print("ZIP đã có sẵn ở local, bỏ qua bước copy.")

if not os.path.exists(LOCAL_EXTRACT_DIR):
    os.makedirs(LOCAL_EXTRACT_DIR, exist_ok=True)
    print("Đang giải nén ZIP ...")
    # !unzip -q "$LOCAL_ZIP_PATH" -d "$LOCAL_EXTRACT_DIR"
    print("Giải nén xong.")
else:
    print("Đã có thư mục local extract, bỏ qua bước giải nén.")
# Out:
# Đang copy ZIP sang local của Colab ...
# Copy ZIP xong.
# Đang giải nén ZIP ...
# Giải nén xong.

# %% [markdown]
# ## 4. Tự tìm thư mục dataset có `train/`, `val/`, `test`

# %%
import os

def find_dataset_root(base_dir):
    for root, dirs, files in os.walk(base_dir):
        dir_names = set(dirs)
        if {"train", "val", "test"}.issubset(dir_names):
            return root
    return None

DATASET_DIR = find_dataset_root(LOCAL_EXTRACT_DIR)
assert DATASET_DIR is not None, "Không tìm thấy thư mục chứa train/val/test sau khi giải nén."

TRAIN_DIR = os.path.join(DATASET_DIR, "train")
VAL_DIR = os.path.join(DATASET_DIR, "val")
TEST_DIR = os.path.join(DATASET_DIR, "test")

print("DATASET_DIR:", DATASET_DIR)
print("TRAIN_DIR  :", TRAIN_DIR)
print("VAL_DIR    :", VAL_DIR)
print("TEST_DIR   :", TEST_DIR)
# Out:
# DATASET_DIR: /content/augmented_dataset_local
# TRAIN_DIR  : /content/augmented_dataset_local/train
# VAL_DIR    : /content/augmented_dataset_local/val
# TEST_DIR   : /content/augmented_dataset_local/test

# %% [markdown]
# ## 5. Import thư viện

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input

np.random.seed(SEED)
tf.random.set_seed(SEED)

print("TensorFlow version:", tf.__version__)
print("GPU:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.19.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 6. Kiểm tra thư mục dữ liệu

# %%
assert os.path.exists(TRAIN_DIR), f"Không tìm thấy train: {TRAIN_DIR}"
assert os.path.exists(VAL_DIR), f"Không tìm thấy val: {VAL_DIR}"
assert os.path.exists(TEST_DIR), f"Không tìm thấy test: {TEST_DIR}"

print("Đã tìm thấy train / val / test")
print("\n10 class đầu tiên trong train:")
for i, name in enumerate(sorted(os.listdir(TRAIN_DIR))[:10], 1):
    print(f"{i}. {name}")
# Out:
# Đã tìm thấy train / val / test
#
# 10 class đầu tiên trong train:
# 1. ABBOTTS BOOBY
# 2. ABYSSINIAN GROUND HORNBILL
# 3. AFRICAN PIED HORNBILL
# 4. AFRICAN PYGMY GOOSE
# 5. ALPINE CHOUGH
# 6. AMERICAN AVOCET
# 7. AMERICAN BITTERN
# 8. AMERICAN DIPPER
# 9. AMERICAN PIPIT
# 10. AMERICAN WIGEON

# %% [markdown]
# ## 7. Tạo dataset từ thư mục ảnh

# %%
train_ds_raw = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    labels="inferred",
    label_mode="int",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=SEED
)

val_ds_raw = tf.keras.utils.image_dataset_from_directory(
    VAL_DIR,
    labels="inferred",
    label_mode="int",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)

test_ds_raw = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR,
    labels="inferred",
    label_mode="int",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)

class_names = train_ds_raw.class_names
num_classes = len(class_names)

print("Số class:", num_classes)
print("10 class đầu tiên:", class_names[:10])
# Out:
# Found 30000 files belonging to 150 classes.
# Found 4248 files belonging to 150 classes.
# Found 4468 files belonging to 150 classes.
# Số class: 150
# 10 class đầu tiên: ['ABBOTTS BOOBY', 'ABYSSINIAN GROUND HORNBILL', 'AFRICAN PIED HORNBILL', 'AFRICAN PYGMY GOOSE', 'ALPINE CHOUGH', 'AMERICAN AVOCET', 'AMERICAN BITTERN', 'AMERICAN DIPPER', 'AMERICAN PIPIT', 'AMERICAN WIGEON']

# %% [markdown]
# ## 8. Tiền xử lý cho VGG16

# %%
def preprocess_batch(x, y):
    x = tf.cast(x, tf.float32)
    x = preprocess_input(x)
    return x, y

train_ds = train_ds_raw.map(preprocess_batch, num_parallel_calls=2).prefetch(1)
val_ds = val_ds_raw.map(preprocess_batch, num_parallel_calls=2).prefetch(1)
test_ds = test_ds_raw.map(preprocess_batch, num_parallel_calls=2).prefetch(1)

print("Số batch train:", tf.data.experimental.cardinality(train_ds).numpy())
print("Số batch val  :", tf.data.experimental.cardinality(val_ds).numpy())
print("Số batch test :", tf.data.experimental.cardinality(test_ds).numpy())
# Out:
# Số batch train: 938
# Số batch val  : 133
# Số batch test : 140

# %% [markdown]
# ## 9. Xem thử một vài ảnh mẫu

# %%
plt.figure(figsize=(12, 8))
for images, labels in train_ds_raw.take(1):
    for i in range(min(9, len(images))):
        plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[int(labels[i])])
        plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10. Xây dựng model VGG16

# %%
base_model = VGG16(
    include_top=False,
    weights="imagenet",
    input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3)
)
base_model.trainable = False

inputs = layers.Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
x = base_model(inputs, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(num_classes, activation="softmax")(x)

model = models.Model(inputs, outputs)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ vgg16 (Functional)              │ (None, 7, 7, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 150)            │        76,950 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,791,638 (56.43 MB)
#  Trainable params: 76,950 (300.59 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %% [markdown]
# ## 11. Callback lưu best model mỗi epoch và ghi learning rate

# %%
best_model_path = os.path.join(OUTPUT_DIR, "best_vgg16.keras")
final_model_path = os.path.join(OUTPUT_DIR, "final_vgg16.keras")
csv_log_path = os.path.join(OUTPUT_DIR, "training_log.csv")

class LrLogger(callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        lr = self.model.optimizer.learning_rate
        if isinstance(lr, tf.keras.optimizers.schedules.LearningRateSchedule):
            current_lr = float(tf.keras.backend.get_value(lr(self.model.optimizer.iterations)))
        else:
            current_lr = float(tf.keras.backend.get_value(lr))
        logs["learning_rate"] = current_lr
        print(f" - learning_rate: {current_lr:.8f}")

callback_list = [
    callbacks.ModelCheckpoint(
        filepath=best_model_path,
        monitor="val_accuracy",
        mode="max",
        save_best_only=True,
        verbose=1
    ),
    callbacks.CSVLogger(csv_log_path),
    callbacks.EarlyStopping(
        monitor="val_accuracy",
        mode="max",
        patience=4,
        restore_best_weights=True,
        verbose=1
    ),
    callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=2,
        verbose=1
    ),
    LrLogger()
]

print("Best model:", best_model_path)
print("Final model:", final_model_path)
print("CSV log:", csv_log_path)
# Out:
# Best model: /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
# Final model: /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/final_vgg16.keras
# CSV log: /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/training_log.csv

# %% [markdown]
# ## 12. Train phase 1
#
# Khi chạy cell này, mỗi epoch sẽ hiện:
# - accuracy
# - loss
# - val_accuracy
# - val_loss
# - learning_rate

# %%
history_phase1 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_HEAD,
    callbacks=callback_list,
    verbose=1
)
# Out:
# Epoch 1/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.2439 - loss: 9.4664
# Epoch 1: val_accuracy improved from None to 0.81615, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00100000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 230s 229ms/step - accuracy: 0.4443 - loss: 5.0199 - val_accuracy: 0.8161 - val_loss: 0.8012 - learning_rate: 0.0010
# Epoch 2/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.7453 - loss: 1.3104
# Epoch 2: val_accuracy improved from 0.81615 to 0.86323, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00100000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 198s 211ms/step - accuracy: 0.7700 - loss: 1.1733 - val_accuracy: 0.8632 - val_loss: 0.6270 - learning_rate: 0.0010
# Epoch 3/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.8212 - loss: 0.8343
# Epoch 3: val_accuracy improved from 0.86323 to 0.88512, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00100000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 200s 213ms/step - accuracy: 0.8290 - loss: 0.7985 - val_accuracy: 0.8851 - val_loss: 0.5864 - learning_rate: 0.0010
# Epoch 4/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.8551 - loss: 0.6768
# Epoch 4: val_accuracy improved from 0.88512 to 0.88653, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00100000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 199s 212ms/step - accuracy: 0.8583 - loss: 0.6565 - val_accuracy: 0.8865 - val_loss: 0.5370 - learning_rate: 0.0010
# Epoch 5/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.8711 - loss: 0.5959
# Epoch 5: val_accuracy improved from 0.88653 to 0.89266, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00100000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 214s 228ms/step - accuracy: 0.8737 - loss: 0.5803 - val_accuracy: 0.8927 - val_loss: 0.5575 - learning_rate: 0.0010
# Epoch 6/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.8833 - loss: 0.5686
# Epoch 6: val_accuracy did not improve from 0.89266
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#  - learning_rate: 0.00050000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 197s 210ms/step - accuracy: 0.8831 - loss: 0.5547 - val_accuracy: 0.8889 - val_loss: 0.6010 - learning_rate: 5.0000e-04
# Epoch 7/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9066 - loss: 0.4186
# Epoch 7: val_accuracy improved from 0.89266 to 0.91408, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 7: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00050000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 197s 210ms/step - accuracy: 0.9103 - loss: 0.3866 - val_accuracy: 0.9141 - val_loss: 0.4627 - learning_rate: 5.0000e-04
# Epoch 8/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9150 - loss: 0.3618
# Epoch 8: val_accuracy did not improve from 0.91408
#  - learning_rate: 0.00050000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 197s 209ms/step - accuracy: 0.9169 - loss: 0.3521 - val_accuracy: 0.9094 - val_loss: 0.4755 - learning_rate: 5.0000e-04
# Epoch 9/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9207 - loss: 0.3219
# Epoch 9: val_accuracy improved from 0.91408 to 0.91455, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 9: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00050000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 197s 210ms/step - accuracy: 0.9224 - loss: 0.3151 - val_accuracy: 0.9145 - val_loss: 0.4542 - learning_rate: 5.0000e-04
# Epoch 10/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9211 - loss: 0.3260
# Epoch 10: val_accuracy improved from 0.91455 to 0.91737, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 10: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00050000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 202s 210ms/step - accuracy: 0.9226 - loss: 0.3123 - val_accuracy: 0.9174 - val_loss: 0.4595 - learning_rate: 5.0000e-04
# Epoch 11/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9267 - loss: 0.3027
# Epoch 11: val_accuracy improved from 0.91737 to 0.91949, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 11: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00050000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 197s 210ms/step - accuracy: 0.9268 - loss: 0.2961 - val_accuracy: 0.9195 - val_loss: 0.4453 - learning_rate: 5.0000e-04
# Epoch 12/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9303 - loss: 0.2699
# Epoch 12: val_accuracy did not improve from 0.91949
#  - learning_rate: 0.00050000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 202s 210ms/step - accuracy: 0.9299 - loss: 0.2741 - val_accuracy: 0.9145 - val_loss: 0.4698 - learning_rate: 5.0000e-04
# Epoch 13/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9286 - loss: 0.2889
# Epoch 13: val_accuracy did not improve from 0.91949
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#  - learning_rate: 0.00025000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 202s 210ms/step - accuracy: 0.9283 - loss: 0.2924 - val_accuracy: 0.9103 - val_loss: 0.4823 - learning_rate: 2.5000e-04
# Epoch 14/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9399 - loss: 0.2300
# Epoch 14: val_accuracy improved from 0.91949 to 0.92420, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 14: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00025000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 197s 210ms/step - accuracy: 0.9427 - loss: 0.2147 - val_accuracy: 0.9242 - val_loss: 0.4083 - learning_rate: 2.5000e-04
# Epoch 15/15
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9406 - loss: 0.2183
# Epoch 15: val_accuracy improved from 0.92420 to 0.92444, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 15: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00025000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 197s 210ms/step - accuracy: 0.9433 - loss: 0.2118 - val_accuracy: 0.9244 - val_loss: 0.3978 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 15.

# %% [markdown]
# ## 13. Fine-tune phase 2
#
# Phase này mở một phần base model để tăng accuracy.

# %%
if EPOCHS_FINE_TUNE > 0:
    base_model.trainable = True

    fine_tune_at = int(len(base_model.layers) * 0.8)
    for layer in base_model.layers[:fine_tune_at]:
        layer.trainable = False

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )

    initial_epoch = len(history_phase1.history["loss"])
    total_epochs = initial_epoch + EPOCHS_FINE_TUNE

    history_phase2 = model.fit(
        train_ds,
        validation_data=val_ds,
        initial_epoch=initial_epoch,
        epochs=total_epochs,
        callbacks=callback_list,
        verbose=1
    )
else:
    history_phase2 = None
    print("Đã bỏ qua fine-tune phase 2.")
# Out:
# Epoch 16/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.9498 - loss: 0.1668
# Epoch 16: val_accuracy improved from 0.92444 to 0.93597, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 16: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00001000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 236s 245ms/step - accuracy: 0.9555 - loss: 0.1424 - val_accuracy: 0.9360 - val_loss: 0.3014 - learning_rate: 1.0000e-05
# Epoch 17/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9679 - loss: 0.1017
# Epoch 17: val_accuracy improved from 0.93597 to 0.93691, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 17: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00001000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 225s 240ms/step - accuracy: 0.9700 - loss: 0.0954 - val_accuracy: 0.9369 - val_loss: 0.2962 - learning_rate: 1.0000e-05
# Epoch 18/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9772 - loss: 0.0735
# Epoch 18: val_accuracy improved from 0.93691 to 0.94068, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 18: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00001000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 262s 239ms/step - accuracy: 0.9774 - loss: 0.0696 - val_accuracy: 0.9407 - val_loss: 0.2929 - learning_rate: 1.0000e-05
# Epoch 19/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9820 - loss: 0.0576
# Epoch 19: val_accuracy improved from 0.94068 to 0.94115, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 19: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00001000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 225s 240ms/step - accuracy: 0.9822 - loss: 0.0569 - val_accuracy: 0.9411 - val_loss: 0.2976 - learning_rate: 1.0000e-05
# Epoch 20/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9829 - loss: 0.0542
# Epoch 20: val_accuracy improved from 0.94115 to 0.94397, saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#
# Epoch 20: finished saving model to /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/best_vgg16.keras
#  - learning_rate: 0.00001000
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 278s 257ms/step - accuracy: 0.9831 - loss: 0.0516 - val_accuracy: 0.9440 - val_loss: 0.2815 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 20.

# %% [markdown]
# ## 14. Lưu model cuối cùng

# %%
model.save(final_model_path)
print("Đã lưu final model tại:", final_model_path)
# Out:
# Đã lưu final model tại: /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/final_vgg16.keras

# %% [markdown]
# ## 15. Gộp lịch sử train và vẽ biểu đồ

# %%
def combine_history(h1, h2=None):
    if h2 is None:
        return h1.history

    hist = {}
    keys = set(h1.history.keys()).union(set(h2.history.keys()))
    for k in keys:
        hist[k] = h1.history.get(k, []) + h2.history.get(k, [])
    return hist

full_history = combine_history(history_phase1, history_phase2)
history_df = pd.DataFrame(full_history)
display(history_df.head())
# Out:
#    learning_rate  accuracy      loss  val_loss  val_accuracy
# 0          0.001  0.444267  5.019936  0.801154      0.816149
# 1          0.001  0.769967  1.173256  0.627020      0.863230
# 2          0.001  0.829000  0.798510  0.586429      0.885122
# 3          0.001  0.858300  0.656538  0.537013      0.886535
# 4          0.001  0.873733  0.580269  0.557459      0.892655

# %%
plt.figure(figsize=(10, 5))
plt.plot(full_history["accuracy"], label="Train Accuracy")
plt.plot(full_history["val_accuracy"], label="Val Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Train vs Validation Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(full_history["loss"], label="Train Loss")
plt.plot(full_history["val_loss"], label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Train vs Validation Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
if "learning_rate" in full_history:
    plt.figure(figsize=(10, 5))
    plt.plot(full_history["learning_rate"], label="Learning Rate")
    plt.xlabel("Epoch")
    plt.ylabel("Learning Rate")
    plt.title("Learning Rate theo Epoch")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
plot_path = os.path.join(OUTPUT_DIR, "accuracy_loss_plot.png")

plt.figure(figsize=(10, 5))
plt.plot(full_history["accuracy"], label="Train Accuracy")
plt.plot(full_history["val_accuracy"], label="Val Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Train vs Validation Accuracy")
plt.legend()
plt.grid(True)
plt.savefig(plot_path, bbox_inches="tight")
plt.close()

print("Đã lưu biểu đồ tại:", plot_path)
# Out:
# Đã lưu biểu đồ tại: /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/accuracy_loss_plot.png

# %% [markdown]
# ## 16. Hàm đánh giá train và test

# %%
def collect_labels_and_predictions(model, dataset):
    y_true = []
    y_pred = []

    for batch_x, batch_y in dataset:
        preds = model.predict(batch_x, verbose=0)
        preds = np.argmax(preds, axis=1)

        y_true.extend(batch_y.numpy().tolist())
        y_pred.extend(preds.tolist())

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    return y_true, y_pred

def evaluate_dataset(model, dataset, split_name):
    y_true, y_pred = collect_labels_and_predictions(model, dataset)

    acc = accuracy_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred, average="macro", zero_division=0)
    rec = recall_score(y_true, y_pred, average="macro", zero_division=0)
    f1 = f1_score(y_true, y_pred, average="macro", zero_division=0)

    print(f"\n===== {split_name.upper()} =====")
    print(f"Accuracy        : {acc:.4f}")
    print(f"Precision macro : {prec:.4f}")
    print(f"Recall macro    : {rec:.4f}")
    print(f"F1 macro        : {f1:.4f}")

    return {
        "split": split_name,
        "accuracy": acc,
        "precision_macro": prec,
        "recall_macro": rec,
        "f1_macro": f1
    }, y_true, y_pred

# %% [markdown]
# ## 17. Đánh giá trên train và test

# %%
train_metrics, y_train_true, y_train_pred = evaluate_dataset(model, train_ds, "train")
test_metrics, y_test_true, y_test_pred = evaluate_dataset(model, test_ds, "test")

metrics_df = pd.DataFrame([train_metrics, test_metrics])
display(metrics_df)
# Out:
# ===== TRAIN =====
# Accuracy        : 0.9997
# Precision macro : 0.9997
# Recall macro    : 0.9997
# F1 macro        : 0.9997
#
# ===== TEST =====
# Accuracy        : 0.9423
# Precision macro : 0.9442
# Recall macro    : 0.9425
# F1 macro        : 0.9423
#    split  accuracy  precision_macro  recall_macro  f1_macro
# 0  train  0.999700         0.999701      0.999700  0.999700
# 1   test  0.942256         0.944246      0.942505  0.942295

# %%
metrics_csv_path = os.path.join(OUTPUT_DIR, "metrics_summary.csv")
metrics_txt_path = os.path.join(OUTPUT_DIR, "metrics_summary.txt")

metrics_df.to_csv(metrics_csv_path, index=False)

with open(metrics_txt_path, "w", encoding="utf-8") as f:
    f.write("KET QUA DANH GIA MO HINH\n")
    f.write("=" * 50 + "\n")
    for row in [train_metrics, test_metrics]:
        f.write(f"Split: {row['split']}\n")
        f.write(f"Accuracy        : {row['accuracy']:.6f}\n")
        f.write(f"Precision macro : {row['precision_macro']:.6f}\n")
        f.write(f"Recall macro    : {row['recall_macro']:.6f}\n")
        f.write(f"F1 macro        : {row['f1_macro']:.6f}\n")
        f.write("-" * 50 + "\n")

print("Đã lưu metrics CSV:", metrics_csv_path)
print("Đã lưu metrics TXT:", metrics_txt_path)
# Out:
# Đã lưu metrics CSV: /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/metrics_summary.csv
# Đã lưu metrics TXT: /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/metrics_summary.txt

# %% [markdown]
# ## 18. Classification report trên tập test

# %%
report = classification_report(
    y_test_true,
    y_test_pred,
    target_names=class_names,
    zero_division=0
)

print(report)

report_path = os.path.join(OUTPUT_DIR, "classification_report_test.txt")
with open(report_path, "w", encoding="utf-8") as f:
    f.write(report)

print("Đã lưu classification report tại:", report_path)
# Out:
#                                precision    recall  f1-score   support
#
#                 ABBOTTS BOOBY       0.86      0.83      0.84        29
#    ABYSSINIAN GROUND HORNBILL       0.91      1.00      0.95        29
#         AFRICAN PIED HORNBILL       0.94      0.97      0.95        30
#           AFRICAN PYGMY GOOSE       0.93      0.97      0.95        29
#                 ALPINE CHOUGH       0.93      1.00      0.96        27
#             RED FACED WARBLER       1.00      1.00      1.00        27
#                      RED FODY       1.00      1.00      1.00        27
#                      RED KNOT       0.97      0.97      0.97        32
#       RED LEGGED HONEYCREEPER       1.00      1.00      1.00        27
#           RED SHOULDERED HAWK       0.89      0.86      0.87        28
#               RED TAILED HAWK       0.75      0.94      0.83        32
#        ROSE BREASTED COCKATOO       0.97      1.00      0.98        31
#        ROSE BREASTED GROSBEAK       1.00      0.96      0.98        28
#             ROSEATE SPOONBILL       1.00      1.00      1.00        31
#          RUBY CROWNED KINGLET       0.93      0.90      0.92        30
#                  RUFOUS TREPE       1.00      0.93      0.96        41
#                 RUFUOS MOTMOT       0.91      1.00      0.95        30
#                SATYR TRAGOPAN       0.93      0.93      0.93        27
#                   SAYS PHOEBE       0.90      0.87      0.89        31
#                      SHOEBILL       1.00      0.93      0.96        28
#                    SNOW GOOSE       0.93      0.87      0.90        30
#                SNOW PARTRIDGE       0.93      0.93      0.93        28
#              SNOWY SHEATHBILL       0.94      1.00      0.97        29
#                          SORA       1.00      0.94      0.97        32
#        SPOTTED WHISTLING DUCK       0.96      0.79      0.87        29
#             STRIATED CARACARA       0.94      0.94      0.94        31
#                    SUNBITTERN       0.93      0.93      0.93        27
#                   SURF SCOTER       0.94      1.00      0.97        29
#             SWINHOES PHEASANT       0.91      0.94      0.93        34
#               TAWNY FROGMOUTH       0.91      0.97      0.94        30
#                  TREE SWALLOW       0.84      0.93      0.89        29
#                 VARIED THRUSH       1.00      0.94      0.97        31
#                         VEERY       0.93      0.90      0.92        30
#                        VERDIN       0.93      0.86      0.89        29
#        VIOLET BACKED STARLING       1.00      0.97      0.98        32
#                 VIOLET CUCKOO       0.90      1.00      0.95        28
#          VIOLET GREEN SWALLOW       0.93      0.88      0.90        32
#          VULTURINE GUINEAFOWL       1.00      1.00      1.00        27
#                  WALL CREAPER       1.00      0.96      0.98        28
#       WHITE EARED HUMMINGBIRD       0.96      0.96      0.96        28
#           WHITE TAILED TROPIC       0.92      0.79      0.85        28
#              WILLOW PTARMIGAN       0.97      1.00      0.98        30
#                     WOOD DUCK       1.00      0.97      0.99        34
#                   WOOD THRUSH       0.91      0.94      0.93        33
#           WOODLAND KINGFISHER       1.00      1.00      1.00        30
#                       WRENTIT       0.93      0.87      0.90        31
#          YELLOW BREASTED CHAT       1.00      1.00      1.00        31
#                    ZEBRA DOVE       1.00      0.93      0.96        27
#
#                      accuracy                           0.94      4468
#                     macro avg       0.94      0.94      0.94      4468
#                  weighted avg       0.94      0.94      0.94      4468
#
# Đã lưu classification report tại: /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs/classification_report_test.txt

# %% [markdown]
# ## 19. Hiển thị một vài ảnh dự đoán đúng và sai

# %%
def show_predictions_from_raw_dataset(raw_dataset, y_pred, class_names, correct=True, max_images=9):
    images_all = []
    labels_all = []

    for images, labels in raw_dataset:
        images_all.append(images.numpy().astype("uint8"))
        labels_all.append(labels.numpy())

    X = np.concatenate(images_all, axis=0)
    y_true = np.concatenate(labels_all, axis=0)

    indices = np.where(y_true == y_pred)[0] if correct else np.where(y_true != y_pred)[0]
    if len(indices) == 0:
        print("Không có ảnh phù hợp để hiển thị.")
        return

    chosen = indices[:max_images]

    plt.figure(figsize=(12, 8))
    for i, idx in enumerate(chosen):
        plt.subplot(3, 3, i + 1)
        plt.imshow(X[idx])
        plt.title(f"T:{class_names[y_true[idx]]}\nP:{class_names[y_pred[idx]]}", fontsize=9)
        plt.axis("off")
    plt.tight_layout()
    plt.show()

print("Một vài ảnh dự đoán đúng:")
show_predictions_from_raw_dataset(test_ds_raw, y_test_pred, class_names, correct=True, max_images=9)

print("Một vài ảnh dự đoán sai:")
show_predictions_from_raw_dataset(test_ds_raw, y_test_pred, class_names, correct=False, max_images=9)
# Out:
# Một vài ảnh dự đoán đúng:
# Một vài ảnh dự đoán sai:

# %% [markdown]
# ## 20. Load lại model tốt nhất nếu cần

# %%
best_loaded_model = tf.keras.models.load_model(best_model_path)
print("Đã load best model từ:", best_model_path)
# Out:
# Đã load best model từ: /content/drive/MyDrive/vgg16_zip_local_128_batch32_outputs_ORI/best_vgg16.keras

# %%
import time
import numpy as np
import tensorflow as tf

# lấy 1 batch từ test_ds
for batch_x, batch_y in test_ds.take(1):
    sample = batch_x[:1]   # 1 ảnh
    break

# warm-up
_ = model.predict(sample, verbose=0)

num_runs = 100
start = time.time()
for _ in range(num_runs):
    _ = model.predict(sample, verbose=0)
end = time.time()

gpu_inference_time = (end - start) / num_runs
print(f"Inference GPU trung bình / 1 ảnh: {gpu_inference_time:.6f} giây")
print(f"~ {gpu_inference_time*1000:.2f} ms / ảnh")
# Out:
# Inference GPU trung bình / 1 ảnh: 0.104280 giây
# ~ 104.28 ms / ảnh

# %%
import time
import tensorflow as tf

# load lại model đã lưu
cpu_model = tf.keras.models.load_model(best_model_path)

for batch_x, batch_y in test_ds.take(1):
    sample = batch_x[:1]
    break

print("Model input shape:", cpu_model.input_shape)
print("Sample shape     :", sample.shape)

# warm-up
_ = cpu_model.predict(sample, verbose=0)

num_runs = 100
start = time.time()
for _ in range(num_runs):
    _ = cpu_model.predict(sample, verbose=0)
end = time.time()

cpu_inference_time = (end - start) / num_runs
print(f"Inference CPU trung bình / 1 ảnh: {cpu_inference_time:.6f} giây")
print(f"~ {cpu_inference_time*1000:.2f} ms / ảnh")
# Out:
# Model input shape: (None, 224, 224, 3)
# Sample shape     : (1, 224, 224, 3)
# Inference CPU trung bình / 1 ảnh: 0.086298 giây
# ~ 86.30 ms / ảnh

# %% [markdown]
# ## 21. Tóm tắt đầu ra đã lưu
#
# Sau khi chạy xong notebook, trong `OUTPUT_DIR` sẽ có:
# - `best_vgg16.keras`
# - `final_vgg16.keras`
# - `training_log.csv`
# - `accuracy_loss_plot.png`
# - `metrics_summary.csv`
# - `metrics_summary.txt`
# - `classification_report_test.txt`
